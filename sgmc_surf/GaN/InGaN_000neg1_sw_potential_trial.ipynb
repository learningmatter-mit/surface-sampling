# %%
import os
import sys
sys.path.append("/home/dux/")
sys.path.append("/home/dux/surface_sampling/sgmc_surf")

from mcmc import mcmc_run, slab_energy

import ase
from ase.calculators.lammpsrun import LAMMPS
from ase.io import read
from ase.build import make_supercell
from catkit.gen.adsorption import get_adsorption_sites

import catkit
import numpy as np

from htvs.djangochem.pgmols.utils import surfaces

# %%
# Ga In N potential
local_potential_folder = "/home/dux/surface_sampling/sgmc_surf/potentials/"
parameters = {
    'pair_style': 'sw',
    'pair_coeff': ['* * InGaN.sw In Ga N']
}
potential_file = os.path.join(local_potential_folder, 'InGaN.sw')

lammps_calc = LAMMPS(files=[potential_file], keep_tmp_files=False, keep_alive=False, tmp_dir="/home/dux/surface_sampling/tmp_files")
lammps_calc.set(**parameters)
# Out:
# {'pair_style': 'sw', 'pair_coeff': ['* * InGaN.sw In Ga N']}

# %%
# Get pristine surface
# GaN 0001 surface
atoms = read('GaN_hexagonal.cif')

# supercell_atoms = atoms*(2,2,2)
# supercell_atoms.write('GaN_hexagonal_2x2.cif')

supercell_atoms = atoms*(3,3,3)
supercell_atoms.write('GaN_hexagonal_3x3.cif')

# might do the opposite layer [0,0,0,1] when the stated layer in ref is [0,0,0,-1]
pristine_slab, surface_atoms = surfaces.surface_from_bulk(supercell_atoms, [0,0,0,-1], size=[3,3], vacuum=10)

# # set surface atoms from the other side
# all_atoms = np.arange(len(slab))
# curr_surf_atoms = slab.get_surface_atoms()
# new_surf_atoms = np.setdiff1d(all_atoms, curr_surf_atoms)
# slab.set_surface_atoms(new_surf_atoms)
# # invert the positions
# slab.set_scaled_positions(1 - slab.get_scaled_positions())

# slab.write('GaN_0001_2x2_pristine_slab.cif')
pristine_slab.write('GaN_neg0001_3x3_pristine_slab.cif')
# Out:
# /home/dux/miniconda3/envs/mlenv/lib/python3.8/site-packages/catkit/gen/surface.py:334: UserWarning: Your slab has no bulk atoms and may be too thin to identify surface atoms correctly. This may cause surface adsorption site identification to fail.
#   warnings.warn(

# %%
# seems like we need at least one of each atom for potential to work
# seed random ads site with In
# read in pristine slab
# pristine_slab = read("GaN_neg0001_3x3_pristine_slab.cif")
pristine_slab.calc = lammps_calc

# get in pymatgen ads sites
all_adsorbed = read("pymatgen_GaN_neg0001_ads_Ga_all_adsorbed_slab.cif")
print(f"all adsorbed {len(all_adsorbed)}")
select_positions = all_adsorbed.get_positions()[len(pristine_slab):]

import random
random_position = random.choice(select_positions)
print(f"inserting In into random pos at {random_position}")

pristine_slab.append('In')
pristine_slab.positions[-1] = random_position

print(f"proper adsorbed energies are {pristine_slab.get_potential_energy()}")
# Out:
# all adsorbed 130
# inserting In into random pos at [ 3.21625784  0.92845366 14.62006795]
# proper adsorbed energies are -100.4921652273823
# /home/dux/miniconda3/envs/mlenv/lib/python3.8/site-packages/ase/calculators/lammpsrun.py:379: UserWarning: semi-periodic ASE cell detected - translation to proper LAMMPS input cell might fail
#   warnings.warn(

# %%
# canonical without relaxation
# adsorb In only for this round
element = 'In'
ads = catkit.gratoms.Gratoms(element)

# starting from more random initial positions
num_ads_atoms = 9 - 1 # this number of nitrogens on the surface, minus 1 already adsorbed indium

num_sweeps = 300
surface_name = "InGaN_0001_3x3"
alpha = 0.99

slab = pristine_slab.copy()
slab.write("InGaN_0001_3x3_starting_slab.cif")

# try positive chem pot
chem_pot = 5
history, energy_hist, frac_accept_hist, adsorption_count_hist = mcmc_run(num_sweeps=num_sweeps, temp=1, pot=chem_pot, alpha=alpha, slab=slab, calc=lammps_calc, surface_name=surface_name, element=element, canonical=True, num_ads_atoms=num_ads_atoms, relax=False, ads_coords=select_positions)
# Out:
# INFO:Running with num_sweeps = 300, temp = 1, pot = 5, alpha = 0.99
# INFO:there are 37 atoms
# INFO:using slab calc <ase.calculators.lammpsrun.LAMMPS object at 0x7f514d89bca0>
# /home/dux/miniconda3/envs/mlenv/lib/python3.8/site-packages/catkit/gen/adsorption.py:60: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   self.r1_topology = np.array(self.r1_topology)
# /home/dux/miniconda3/envs/mlenv/lib/python3.8/site-packages/catkit/gen/adsorption.py:61: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   self.r2_topology = np.array(self.r2_topology)
# INFO:In pristine slab, there are a total of 94 sites
# /home/dux/miniconda3/envs/mlenv/lib/python3.8/site-packages/ase/calculators/lammpsrun.py:379: UserWarning: semi-periodic ASE cell detected - translation to proper LAMMPS input cell might fail
#   warnings.warn(
# INFO:running for 94 iterations per run over a total of 300 runs
# INFO:adsorbate is In
# INFO:In sweep 1 out of 300
# INFO:optim structure has Energy = -113.6176214358362
# INFO:In sweep 2 out of 300
# INFO:optim structure has Energy = -114.9846558144825
# INFO:In sweep 3 out of 300
# INFO:optim structure has Energy = -113.7558353563407
# INFO:In sweep 4 out of 300
# INFO:optim structure has Energy = -112.77070326841
# INFO:In sweep 5 out of 300
# INFO:optim structure has Energy = -114.048237037256
# INFO:In sweep 6 out of 300
# INFO:optim structure has Energy = -112.7298149279064
# INFO:In sweep 7 out of 300
# INFO:optim structure has Energy = -109.7235527570224
# INFO:In sweep 8 out of 300
# INFO:optim structure has Energy = -110.5598872260213
# INFO:In sweep 9 out of 300
# INFO:optim structure has Energy = -109.9215435845497
# INFO:In sweep 10 out of 300
# INFO:optim structure has Energy = -112.4483841654454
# INFO:In sweep 11 out of 300
# INFO:optim structure has Energy = -105.4581543251645
# INFO:In sweep 12 out of 300
# INFO:optim structure has Energy = -112.7663489527555
# INFO:In sweep 13 out of 300
# INFO:optim structure has Energy = -113.1492034140848
# INFO:In sweep 14 out of 300
# INFO:optim structure has Energy = -114.1994947706775
# INFO:In sweep 15 out of 300
# INFO:optim structure has Energy = -115.5918824811825
# INFO:In sweep 16 out of 300
# INFO:optim structure has Energy = -112.767757291716
# INFO:In sweep 17 out of 300
# INFO:optim structure has Energy = -114.3412742000646
# INFO:In sweep 18 out of 300
# INFO:optim structure has Energy = -107.6715973029671
# INFO:In sweep 19 out of 300
# INFO:optim structure has Energy = -110.2488124107909
# INFO:In sweep 20 out of 300
# INFO:optim structure has Energy = -111.845061001623
# INFO:In sweep 21 out of 300
# INFO:optim structure has Energy = -113.7339745434346
# INFO:In sweep 22 out of 300
# INFO:optim structure has Energy = -114.0702749368347
# INFO:In sweep 23 out of 300
# INFO:optim structure has Energy = -116.1450808917928
# INFO:In sweep 24 out of 300
# INFO:optim structure has Energy = -112.2782468345096
# INFO:In sweep 25 out of 300
# INFO:optim structure has Energy = -111.3387045740419
# INFO:In sweep 26 out of 300
# INFO:optim structure has Energy = -111.9978730989256
# INFO:In sweep 27 out of 300
# INFO:optim structure has Energy = -111.4377685255406
# INFO:In sweep 28 out of 300
# INFO:optim structure has Energy = -114.2068351464605
# INFO:In sweep 29 out of 300
# INFO:optim structure has Energy = -114.8921149036364
# INFO:In sweep 30 out of 300
# INFO:optim structure has Energy = -115.7017723647447
# INFO:In sweep 31 out of 300
# INFO:optim structure has Energy = -115.5217752729575
# INFO:In sweep 32 out of 300
# INFO:optim structure has Energy = -114.529912485024
# INFO:In sweep 33 out of 300
# INFO:optim structure has Energy = -114.829509409004
# INFO:In sweep 34 out of 300
# INFO:optim structure has Energy = -116.3133793191398
# INFO:In sweep 35 out of 300
# INFO:optim structure has Energy = -114.8198178985849
# INFO:In sweep 36 out of 300
# INFO:optim structure has Energy = -113.5945668631253
# INFO:In sweep 37 out of 300
# INFO:optim structure has Energy = -115.724340084831
# INFO:In sweep 38 out of 300
# INFO:optim structure has Energy = -113.9957279575014
# INFO:In sweep 39 out of 300
# INFO:optim structure has Energy = -111.6166807801085
# INFO:In sweep 40 out of 300
# INFO:optim structure has Energy = -110.5494876293707
# INFO:In sweep 41 out of 300
# INFO:optim structure has Energy = -116.0777144191173
# INFO:In sweep 42 out of 300
# INFO:optim structure has Energy = -113.3529823365478
# INFO:In sweep 43 out of 300
# INFO:optim structure has Energy = -115.6211575150453
# INFO:In sweep 44 out of 300
# INFO:optim structure has Energy = -115.1862537184667
# INFO:In sweep 45 out of 300
# INFO:optim structure has Energy = -113.775075513572
# INFO:In sweep 46 out of 300
# INFO:optim structure has Energy = -115.8949262544019
# INFO:In sweep 47 out of 300
# INFO:optim structure has Energy = -113.3930155367665
# INFO:In sweep 48 out of 300
# INFO:optim structure has Energy = -114.0696873083792
# INFO:In sweep 49 out of 300
# INFO:optim structure has Energy = -113.9754494061481
# INFO:In sweep 50 out of 300
# INFO:optim structure has Energy = -113.6017684034276
# INFO:In sweep 51 out of 300
# INFO:optim structure has Energy = -113.6444907883532
# INFO:In sweep 52 out of 300
# INFO:optim structure has Energy = -112.2542651170403
# INFO:In sweep 53 out of 300
# INFO:optim structure has Energy = -113.6192813315942
# INFO:In sweep 54 out of 300
# INFO:optim structure has Energy = -112.3027567057527
# INFO:In sweep 55 out of 300
# INFO:optim structure has Energy = -113.2122907431359
# INFO:In sweep 56 out of 300
# INFO:optim structure has Energy = -113.0209448321474
# INFO:In sweep 57 out of 300
# INFO:optim structure has Energy = -116.1973341038158
# INFO:In sweep 58 out of 300
# INFO:optim structure has Energy = -114.4673078468582
# INFO:In sweep 59 out of 300
# INFO:optim structure has Energy = -115.5879018702988
# INFO:In sweep 60 out of 300
# INFO:optim structure has Energy = -115.1867109181156
# INFO:In sweep 61 out of 300
# INFO:optim structure has Energy = -114.9694224437077
# INFO:In sweep 62 out of 300
# INFO:optim structure has Energy = -114.9295576558869
# INFO:In sweep 63 out of 300
# INFO:optim structure has Energy = -114.5016192504238
# INFO:In sweep 64 out of 300
# INFO:optim structure has Energy = -113.3977743971976
# INFO:In sweep 65 out of 300
# INFO:optim structure has Energy = -112.9523329667554
# INFO:In sweep 66 out of 300
# INFO:optim structure has Energy = -113.480050323341
# INFO:In sweep 67 out of 300
# INFO:optim structure has Energy = -112.6903990641966
# INFO:In sweep 68 out of 300
# INFO:optim structure has Energy = -114.1387062131644
# INFO:In sweep 69 out of 300
# INFO:optim structure has Energy = -115.1604162881479
# INFO:In sweep 70 out of 300
# INFO:optim structure has Energy = -115.27753312409
# INFO:In sweep 71 out of 300
# INFO:optim structure has Energy = -114.9790751830694
# INFO:In sweep 72 out of 300
# INFO:optim structure has Energy = -115.5048702769854
# INFO:In sweep 73 out of 300
# INFO:optim structure has Energy = -113.7143122016726
# INFO:In sweep 74 out of 300
# INFO:optim structure has Energy = -115.0587923473969
# INFO:In sweep 75 out of 300
# INFO:optim structure has Energy = -115.1828889646707
# INFO:In sweep 76 out of 300
# INFO:optim structure has Energy = -114.6295836739297
# INFO:In sweep 77 out of 300
# INFO:optim structure has Energy = -116.7664261053997
# INFO:In sweep 78 out of 300
# INFO:optim structure has Energy = -116.7664261053997
# INFO:In sweep 79 out of 300
# INFO:optim structure has Energy = -117.5879329341881
# INFO:In sweep 80 out of 300
# INFO:optim structure has Energy = -116.155802339571
# INFO:In sweep 81 out of 300
# INFO:optim structure has Energy = -116.155802339571
# INFO:In sweep 82 out of 300
# INFO:optim structure has Energy = -116.5125455173396
# INFO:In sweep 83 out of 300
# INFO:optim structure has Energy = -116.5025068440973
# INFO:In sweep 84 out of 300
# INFO:optim structure has Energy = -115.4784073635312
# INFO:In sweep 85 out of 300
# INFO:optim structure has Energy = -115.6361615333006
# INFO:In sweep 86 out of 300
# INFO:optim structure has Energy = -115.4090425724994
# INFO:In sweep 87 out of 300
# INFO:optim structure has Energy = -114.8936836791357
# INFO:In sweep 88 out of 300
# INFO:optim structure has Energy = -114.6484446201983
# INFO:In sweep 89 out of 300
# INFO:optim structure has Energy = -115.876964600087
# INFO:In sweep 90 out of 300
# INFO:optim structure has Energy = -117.3090396415306
# INFO:In sweep 91 out of 300
# INFO:optim structure has Energy = -117.3090396415306
# INFO:In sweep 92 out of 300
# INFO:optim structure has Energy = -117.3090396415306
# INFO:In sweep 93 out of 300
# INFO:optim structure has Energy = -116.3307120078809
# INFO:In sweep 94 out of 300
# INFO:optim structure has Energy = -117.4705689673871
# INFO:In sweep 95 out of 300
# INFO:optim structure has Energy = -117.6851155212464
# INFO:In sweep 96 out of 300
# INFO:optim structure has Energy = -117.2908187834877
# INFO:In sweep 97 out of 300
# INFO:optim structure has Energy = -117.1356661010592
# INFO:In sweep 98 out of 300
# INFO:optim structure has Energy = -117.1356661010592
# INFO:In sweep 99 out of 300
# INFO:optim structure has Energy = -116.0940589990156
# INFO:In sweep 100 out of 300
# INFO:optim structure has Energy = -116.1234799429693
# INFO:In sweep 101 out of 300
# INFO:optim structure has Energy = -116.4779633472744
# INFO:In sweep 102 out of 300
# INFO:optim structure has Energy = -116.3926116777983
# INFO:In sweep 103 out of 300
# INFO:optim structure has Energy = -115.6755185212956
# INFO:In sweep 104 out of 300
# INFO:optim structure has Energy = -116.216208548655
# INFO:In sweep 105 out of 300
# INFO:optim structure has Energy = -117.4625103425419
# INFO:In sweep 106 out of 300
# INFO:optim structure has Energy = -117.9488493753871
# INFO:In sweep 107 out of 300
# INFO:optim structure has Energy = -116.5339810091264
# INFO:In sweep 108 out of 300
# INFO:optim structure has Energy = -116.3802149633718
# INFO:In sweep 109 out of 300
# INFO:optim structure has Energy = -116.2878714066574
# INFO:In sweep 110 out of 300
# INFO:optim structure has Energy = -118.5706123066103
# INFO:In sweep 111 out of 300
# INFO:optim structure has Energy = -118.5636873338472
# INFO:In sweep 112 out of 300
# INFO:optim structure has Energy = -116.7531343069503
# INFO:In sweep 113 out of 300
# INFO:optim structure has Energy = -118.2231800380613
# INFO:In sweep 114 out of 300
# INFO:optim structure has Energy = -117.5433033517988
# INFO:In sweep 115 out of 300
# INFO:optim structure has Energy = -117.5565882411107
# INFO:In sweep 116 out of 300
# INFO:optim structure has Energy = -117.5565882411107
# INFO:In sweep 117 out of 300
# INFO:optim structure has Energy = -117.6625039938637
# INFO:In sweep 118 out of 300
# INFO:optim structure has Energy = -117.3924451585341
# INFO:In sweep 119 out of 300
# INFO:optim structure has Energy = -117.3924451585341
# INFO:In sweep 120 out of 300
# INFO:optim structure has Energy = -117.8759727288359
# INFO:In sweep 121 out of 300
# INFO:optim structure has Energy = -117.8759727288359
# INFO:In sweep 122 out of 300
# INFO:optim structure has Energy = -117.8759727288359
# INFO:In sweep 123 out of 300
# INFO:optim structure has Energy = -117.8759727288359
# INFO:In sweep 124 out of 300
# INFO:optim structure has Energy = -117.3200639156257
# INFO:In sweep 125 out of 300
# INFO:optim structure has Energy = -117.3200639156257
# INFO:In sweep 126 out of 300
# INFO:optim structure has Energy = -117.0502449870558
# INFO:In sweep 127 out of 300
# INFO:optim structure has Energy = -117.2455296355487
# INFO:In sweep 128 out of 300
# INFO:optim structure has Energy = -117.320364397754
# INFO:In sweep 129 out of 300
# INFO:optim structure has Energy = -117.3199439303768
# INFO:In sweep 130 out of 300
# INFO:optim structure has Energy = -117.5879329341881
# INFO:In sweep 131 out of 300
# INFO:optim structure has Energy = -117.6259208914772
# INFO:In sweep 132 out of 300
# INFO:optim structure has Energy = -117.6562814361213
# INFO:In sweep 133 out of 300
# INFO:optim structure has Energy = -117.9242289508948
# INFO:In sweep 134 out of 300
# INFO:optim structure has Energy = -117.0973200473852
# INFO:In sweep 135 out of 300
# INFO:optim structure has Energy = -116.9774320135528
# INFO:In sweep 136 out of 300
# INFO:optim structure has Energy = -116.4413101055346
# INFO:In sweep 137 out of 300
# INFO:optim structure has Energy = -116.716690582239
# INFO:In sweep 138 out of 300
# INFO:optim structure has Energy = -115.9239221253429
# INFO:In sweep 139 out of 300
# INFO:optim structure has Energy = -116.3203301257316
# INFO:In sweep 140 out of 300
# INFO:optim structure has Energy = -116.3203301257316
# INFO:In sweep 141 out of 300
# INFO:optim structure has Energy = -115.6167133892829
# INFO:In sweep 142 out of 300
# INFO:optim structure has Energy = -116.9621410335461
# INFO:In sweep 143 out of 300
# INFO:optim structure has Energy = -116.9621410335462
# INFO:In sweep 144 out of 300
# INFO:optim structure has Energy = -116.9621410335462
# INFO:In sweep 145 out of 300
# INFO:optim structure has Energy = -116.3311566669337
# INFO:In sweep 146 out of 300
# INFO:optim structure has Energy = -117.2979825563814
# INFO:In sweep 147 out of 300
# INFO:optim structure has Energy = -117.4625103425419
# INFO:In sweep 148 out of 300
# INFO:optim structure has Energy = -116.3417290940131
# INFO:In sweep 149 out of 300
# INFO:optim structure has Energy = -117.1369604238913
# INFO:In sweep 150 out of 300
# INFO:optim structure has Energy = -117.4403202869656
# INFO:In sweep 151 out of 300
# INFO:optim structure has Energy = -117.4403202869656
# INFO:In sweep 152 out of 300
# INFO:optim structure has Energy = -117.4403202869656
# INFO:In sweep 153 out of 300
# INFO:optim structure has Energy = -117.9488493753871
# INFO:In sweep 154 out of 300
# INFO:optim structure has Energy = -118.5706123066103
# INFO:In sweep 155 out of 300
# INFO:optim structure has Energy = -118.5706123066103
# INFO:In sweep 156 out of 300
# INFO:optim structure has Energy = -118.5706123066103
# INFO:In sweep 157 out of 300
# INFO:optim structure has Energy = -118.5706123066103
# INFO:In sweep 158 out of 300
# INFO:optim structure has Energy = -118.5706123066103
# INFO:In sweep 159 out of 300
# INFO:optim structure has Energy = -118.5706123066103
# INFO:In sweep 160 out of 300
# INFO:optim structure has Energy = -118.5706123066103
# INFO:In sweep 161 out of 300
# INFO:optim structure has Energy = -118.5706123066103
# INFO:In sweep 162 out of 300
# INFO:optim structure has Energy = -118.5706123066103
# INFO:In sweep 163 out of 300
# INFO:optim structure has Energy = -118.5706123066103
# INFO:In sweep 164 out of 300
# INFO:optim structure has Energy = -118.5706123066103
# INFO:In sweep 165 out of 300
# INFO:optim structure has Energy = -118.5706123066103
# INFO:In sweep 166 out of 300
# INFO:optim structure has Energy = -118.5706123066103
# INFO:In sweep 167 out of 300
# INFO:optim structure has Energy = -118.5706123066103
# INFO:In sweep 168 out of 300
# INFO:optim structure has Energy = -118.5706123066103
# INFO:In sweep 169 out of 300
# INFO:optim structure has Energy = -118.5706123066103
# INFO:In sweep 170 out of 300
# INFO:optim structure has Energy = -118.5706123066103
# INFO:In sweep 171 out of 300
# INFO:optim structure has Energy = -118.5706123066103
# INFO:In sweep 172 out of 300
# INFO:optim structure has Energy = -118.5706123066103
# INFO:In sweep 173 out of 300
# INFO:optim structure has Energy = -118.5706123066103
# INFO:In sweep 174 out of 300
# INFO:optim structure has Energy = -118.5706123066103
# INFO:In sweep 175 out of 300
# INFO:optim structure has Energy = -118.5706123066103
# INFO:In sweep 176 out of 300
# INFO:optim structure has Energy = -118.5706123066103
# INFO:In sweep 177 out of 300
# INFO:optim structure has Energy = -118.5706123066103
# INFO:In sweep 178 out of 300
# INFO:optim structure has Energy = -118.5706123066103
# INFO:In sweep 179 out of 300
# INFO:optim structure has Energy = -118.5706123066103
# INFO:In sweep 180 out of 300
# INFO:optim structure has Energy = -118.5706123066103
# INFO:In sweep 181 out of 300
# INFO:optim structure has Energy = -118.5706123066103
# INFO:In sweep 182 out of 300
# INFO:optim structure has Energy = -118.5706123066103
# INFO:In sweep 183 out of 300
# INFO:optim structure has Energy = -118.5706123066103
# INFO:In sweep 184 out of 300
# INFO:optim structure has Energy = -118.5706123066103
# INFO:In sweep 185 out of 300
# INFO:optim structure has Energy = -118.5706123066103
# INFO:In sweep 186 out of 300
# INFO:optim structure has Energy = -118.5706123066103
# INFO:In sweep 187 out of 300
# INFO:optim structure has Energy = -118.5706123066103
# INFO:In sweep 188 out of 300
# INFO:optim structure has Energy = -118.5706123066103
# INFO:In sweep 189 out of 300
# INFO:optim structure has Energy = -118.5706123066103
# INFO:In sweep 190 out of 300
# INFO:optim structure has Energy = -118.5706123066103
# INFO:In sweep 191 out of 300
# INFO:optim structure has Energy = -118.5706123066103
# INFO:In sweep 192 out of 300
# INFO:optim structure has Energy = -118.5706123066103
# INFO:In sweep 193 out of 300
# INFO:optim structure has Energy = -118.5706123066103
# INFO:In sweep 194 out of 300
# INFO:optim structure has Energy = -118.5706123066103
# INFO:In sweep 195 out of 300
# INFO:optim structure has Energy = -118.5706123066103
# INFO:In sweep 196 out of 300
# INFO:optim structure has Energy = -118.5706123066103
# INFO:In sweep 197 out of 300
# INFO:optim structure has Energy = -118.5706123066103
# INFO:In sweep 198 out of 300
# INFO:optim structure has Energy = -118.5706123066103
# INFO:In sweep 199 out of 300
# INFO:optim structure has Energy = -118.5706123066103
# INFO:In sweep 200 out of 300
# INFO:optim structure has Energy = -118.5706123066103
# INFO:In sweep 201 out of 300
# INFO:optim structure has Energy = -118.5706123066103
# INFO:In sweep 202 out of 300
# INFO:optim structure has Energy = -118.5706123066103
# INFO:In sweep 203 out of 300
# INFO:optim structure has Energy = -118.5706123066103
# INFO:In sweep 204 out of 300
# INFO:optim structure has Energy = -118.5706123066103
# INFO:In sweep 205 out of 300
# INFO:optim structure has Energy = -118.5706123066103
# INFO:In sweep 206 out of 300
# INFO:optim structure has Energy = -118.5706123066103
# INFO:In sweep 207 out of 300
# INFO:optim structure has Energy = -118.5706123066103
# INFO:In sweep 208 out of 300
# INFO:optim structure has Energy = -118.5706123066103
# INFO:In sweep 209 out of 300
# INFO:optim structure has Energy = -118.5706123066103
# INFO:In sweep 210 out of 300
# INFO:optim structure has Energy = -118.5706123066103
# INFO:In sweep 211 out of 300
# INFO:optim structure has Energy = -118.5706123066103
# INFO:In sweep 212 out of 300
# INFO:optim structure has Energy = -118.5706123066103
# INFO:In sweep 213 out of 300
# INFO:optim structure has Energy = -118.5706123066103
# INFO:In sweep 214 out of 300
# INFO:optim structure has Energy = -118.5706123066103
# INFO:In sweep 215 out of 300
# INFO:optim structure has Energy = -118.5706123066103
# INFO:In sweep 216 out of 300
# INFO:optim structure has Energy = -118.5706123066103
# INFO:In sweep 217 out of 300
# INFO:optim structure has Energy = -118.5706123066103
# INFO:In sweep 218 out of 300
# INFO:optim structure has Energy = -118.5706123066103
# INFO:In sweep 219 out of 300
# INFO:optim structure has Energy = -118.5706123066103
# INFO:In sweep 220 out of 300
# INFO:optim structure has Energy = -118.5706123066103
# INFO:In sweep 221 out of 300
# INFO:optim structure has Energy = -118.5706123066103
# INFO:In sweep 222 out of 300
# INFO:optim structure has Energy = -118.5706123066103
# INFO:In sweep 223 out of 300
# INFO:optim structure has Energy = -118.5706123066103
# INFO:In sweep 224 out of 300
# INFO:optim structure has Energy = -118.5706123066103
# INFO:In sweep 225 out of 300
# INFO:optim structure has Energy = -118.5706123066103
# INFO:In sweep 226 out of 300
# INFO:optim structure has Energy = -118.5706123066103
# INFO:In sweep 227 out of 300
# INFO:optim structure has Energy = -118.5706123066103
# INFO:In sweep 228 out of 300
# INFO:optim structure has Energy = -118.5706123066103
# INFO:In sweep 229 out of 300
# INFO:optim structure has Energy = -118.5706123066103
# INFO:In sweep 230 out of 300
# INFO:optim structure has Energy = -118.5706123066103
# INFO:In sweep 231 out of 300
# INFO:optim structure has Energy = -118.5706123066103
# INFO:In sweep 232 out of 300
# INFO:optim structure has Energy = -118.5706123066103
# INFO:In sweep 233 out of 300
# INFO:optim structure has Energy = -118.5706123066103
# INFO:In sweep 234 out of 300
# INFO:optim structure has Energy = -118.5706123066103
# INFO:In sweep 235 out of 300
# INFO:optim structure has Energy = -118.5706123066103
# INFO:In sweep 236 out of 300
# INFO:optim structure has Energy = -118.5706123066103
# INFO:In sweep 237 out of 300
# INFO:optim structure has Energy = -118.5706123066103
# INFO:In sweep 238 out of 300
# INFO:optim structure has Energy = -118.5706123066103
# INFO:In sweep 239 out of 300
# INFO:optim structure has Energy = -118.5706123066103
# INFO:In sweep 240 out of 300
# INFO:optim structure has Energy = -118.5706123066103
# INFO:In sweep 241 out of 300
# INFO:optim structure has Energy = -118.5706123066103
# INFO:In sweep 242 out of 300
# INFO:optim structure has Energy = -118.5706123066103
# INFO:In sweep 243 out of 300
# INFO:optim structure has Energy = -118.5706123066103
# INFO:In sweep 244 out of 300
# INFO:optim structure has Energy = -118.5706123066103
# INFO:In sweep 245 out of 300
# INFO:optim structure has Energy = -118.5706123066103
# INFO:In sweep 246 out of 300
# INFO:optim structure has Energy = -118.5706123066103
# INFO:In sweep 247 out of 300
# INFO:optim structure has Energy = -118.5706123066103
# INFO:In sweep 248 out of 300
# INFO:optim structure has Energy = -118.5706123066103
# INFO:In sweep 249 out of 300
# INFO:optim structure has Energy = -118.5706123066103
# INFO:In sweep 250 out of 300
# INFO:optim structure has Energy = -118.5706123066103
# INFO:In sweep 251 out of 300
# INFO:optim structure has Energy = -118.5706123066103
# INFO:In sweep 252 out of 300
# INFO:optim structure has Energy = -118.5706123066103
# INFO:In sweep 253 out of 300
# INFO:optim structure has Energy = -118.5706123066103
# INFO:In sweep 254 out of 300
# INFO:optim structure has Energy = -118.5706123066103
# INFO:In sweep 255 out of 300
# INFO:optim structure has Energy = -118.5706123066103
# INFO:In sweep 256 out of 300
# INFO:optim structure has Energy = -118.5706123066103
# INFO:In sweep 257 out of 300
# INFO:optim structure has Energy = -118.5706123066103
# INFO:In sweep 258 out of 300
# INFO:optim structure has Energy = -118.5706123066103
# INFO:In sweep 259 out of 300
# INFO:optim structure has Energy = -118.5706123066103
# INFO:In sweep 260 out of 300
# INFO:optim structure has Energy = -118.5706123066103
# INFO:In sweep 261 out of 300
# INFO:optim structure has Energy = -118.5706123066103
# INFO:In sweep 262 out of 300
# INFO:optim structure has Energy = -118.5706123066103
# INFO:In sweep 263 out of 300
# INFO:optim structure has Energy = -118.5706123066103
# INFO:In sweep 264 out of 300
# INFO:optim structure has Energy = -118.5706123066103
# INFO:In sweep 265 out of 300
# INFO:optim structure has Energy = -118.5706123066102
# INFO:In sweep 266 out of 300
# INFO:optim structure has Energy = -118.5706123066102
# INFO:In sweep 267 out of 300
# INFO:optim structure has Energy = -118.5706123066102
# INFO:In sweep 268 out of 300
# INFO:optim structure has Energy = -118.5706123066102
# INFO:In sweep 269 out of 300
# INFO:optim structure has Energy = -118.5706123066102
# INFO:In sweep 270 out of 300
# INFO:optim structure has Energy = -118.5706123066102
# INFO:In sweep 271 out of 300
# INFO:optim structure has Energy = -118.5706123066102
# INFO:In sweep 272 out of 300
# INFO:optim structure has Energy = -118.5706123066102
# INFO:In sweep 273 out of 300
# INFO:optim structure has Energy = -118.5706123066102
# INFO:In sweep 274 out of 300
# INFO:optim structure has Energy = -118.5706123066102
# INFO:In sweep 275 out of 300
# INFO:optim structure has Energy = -118.5706123066102
# INFO:In sweep 276 out of 300
# INFO:optim structure has Energy = -118.5706123066102
# INFO:In sweep 277 out of 300
# INFO:optim structure has Energy = -118.5706123066102
# INFO:In sweep 278 out of 300
# INFO:optim structure has Energy = -118.5706123066102
# INFO:In sweep 279 out of 300
# INFO:optim structure has Energy = -118.5706123066102
# INFO:In sweep 280 out of 300
# INFO:optim structure has Energy = -118.5706123066102
# INFO:In sweep 281 out of 300
# INFO:optim structure has Energy = -118.5706123066102
# INFO:In sweep 282 out of 300
# INFO:optim structure has Energy = -118.5706123066102
# INFO:In sweep 283 out of 300
# INFO:optim structure has Energy = -118.5706123066102
# INFO:In sweep 284 out of 300
# INFO:optim structure has Energy = -118.5706123066102
# INFO:In sweep 285 out of 300
# INFO:optim structure has Energy = -118.5706123066102
# INFO:In sweep 286 out of 300
# INFO:optim structure has Energy = -118.5706123066102
# INFO:In sweep 287 out of 300
# INFO:optim structure has Energy = -118.5706123066102
# INFO:In sweep 288 out of 300
# INFO:optim structure has Energy = -118.5706123066102
# INFO:In sweep 289 out of 300
# INFO:optim structure has Energy = -118.5706123066102
# INFO:In sweep 290 out of 300
# INFO:optim structure has Energy = -118.5706123066102
# INFO:In sweep 291 out of 300
# INFO:optim structure has Energy = -118.5706123066102
# INFO:In sweep 292 out of 300
# INFO:optim structure has Energy = -118.5706123066102
# INFO:In sweep 293 out of 300
# INFO:optim structure has Energy = -118.5706123066102
# INFO:In sweep 294 out of 300
# INFO:optim structure has Energy = -118.5706123066102
# INFO:In sweep 295 out of 300
# INFO:optim structure has Energy = -118.5706123066102
# INFO:In sweep 296 out of 300
# INFO:optim structure has Energy = -118.5706123066102
# INFO:In sweep 297 out of 300
# INFO:optim structure has Energy = -118.5706123066102
# INFO:In sweep 298 out of 300
# INFO:optim structure has Energy = -118.5706123066102
# INFO:In sweep 299 out of 300
# INFO:optim structure has Energy = -118.5706123066102
# INFO:In sweep 300 out of 300
# INFO:optim structure has Energy = -118.5706123066102

# %%
import matplotlib.pyplot as plt
runs = range(1, num_sweeps+1)

# do the plots
fig, ax = plt.subplots(2, 2, figsize=(10, 8))
ax[0, 0].plot(runs, energy_hist)
ax[0, 0].set_xlabel("Iter")
ax[0, 0].set_ylabel("Energy (E)")
ax[0, 0].set_title("Energy (E) vs Sweeps")

ax[0, 1].plot(runs, frac_accept_hist)
ax[0, 1].set_xlabel("Iter")
ax[0, 1].set_ylabel("Fraction accepted")
ax[0, 1].set_title("Fraction accepted vs Sweeps")

ax[1, 1].plot(runs, np.array(list(adsorption_count_hist.values())).T)
ax[1, 1].set_xlabel("Iter")
ax[1, 1].set_ylabel("Adsorption count")
ax[1, 1].legend(adsorption_count_hist.keys())
ax[1, 1].set_title("Adsorption count vs Iterations")

fig.show()
fig.tight_layout()

# %% [markdown]
# Manually do some adsorptions to make sure the potential works well
