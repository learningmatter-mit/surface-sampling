# %%
import os
import sys
sys.path.append("/home/dux/")
sys.path.append("/home/dux/surface_sampling/sgmc_surf")

from mcmc import mcmc_run, slab_energy

import ase
from ase.calculators.lammpsrun import LAMMPS
from ase.io import read
from ase.build import make_supercell
from catkit.gen.adsorption import get_adsorption_sites

import catkit
import numpy as np

from htvs.djangochem.pgmols.utils import surfaces

# %%
# Ga In N potential
# local_potential_folder = "/home/dux/surface_sampling/sgmc_surf/potentials/"
parameters = {
    'pair_style': 'meam',
    'pair_coeff': ['* * library.meam Ga In N GaN.meam Ga In N']
}
library_file = 'library.meam'
potential_file = 'GaN.meam'

lammps_calc = LAMMPS(files=[library_file, potential_file], keep_tmp_files=False, keep_alive=False, tmp_dir="/home/dux/surface_sampling/tmp_files")
lammps_calc.set(**parameters)
# Out:
# {'pair_style': 'meam',
#  'pair_coeff': ['* * library.meam Ga In N GaN.meam Ga In N']}

# %%
# Get pristine surface
# GaN 0001 surface
atoms = read('GaN_hexagonal.cif')

# supercell_atoms = atoms*(2,2,2)
# supercell_atoms.write('GaN_hexagonal_2x2.cif')

supercell_atoms = atoms*(3,3,3)
supercell_atoms.write('GaN_hexagonal_3x3.cif')

# might do the opposite layer [0,0,0,1] when the stated layer in ref is [0,0,0,-1]
pristine_slab, surface_atoms = surfaces.surface_from_bulk(supercell_atoms, [0,0,0,-1], size=[3,3], vacuum=10)

# # set surface atoms from the other side
# all_atoms = np.arange(len(slab))
# curr_surf_atoms = slab.get_surface_atoms()
# new_surf_atoms = np.setdiff1d(all_atoms, curr_surf_atoms)
# slab.set_surface_atoms(new_surf_atoms)
# # invert the positions
# slab.set_scaled_positions(1 - slab.get_scaled_positions())

# slab.write('GaN_0001_2x2_pristine_slab.cif')
pristine_slab.write('GaN_neg0001_3x3_pristine_slab.cif')
# Out:
# /home/dux/miniconda3/envs/mlenv/lib/python3.8/site-packages/catkit/gen/surface.py:334: UserWarning: Your slab has no bulk atoms and may be too thin to identify surface atoms correctly. This may cause surface adsorption site identification to fail.
#   warnings.warn(

# %%
# seems like we need at least one of each atom for potential to work
# seed random ads site with In
# read in pristine slab
# pristine_slab = read("GaN_neg0001_3x3_pristine_slab.cif")
pristine_slab.calc = lammps_calc

# get in pymatgen ads sites
all_adsorbed = read("pymatgen_GaN_neg0001_ads_Ga_all_adsorbed_slab.cif")
print(f"all adsorbed {len(all_adsorbed)}")
select_positions = all_adsorbed.get_positions()[len(pristine_slab):]

import random
random_position = random.choice(select_positions)
print(f"inserting In into random pos at {random_position}")

pristine_slab.append('In')
pristine_slab.positions[-1] = random_position

print(f"proper adsorbed energies are {pristine_slab.get_potential_energy()}")
# Out:
# all adsorbed 130
# inserting In into random pos at [ 8.84480554  0.46422683 14.94288093]
# proper adsorbed energies are -206.5084362388556
# /home/dux/miniconda3/envs/mlenv/lib/python3.8/site-packages/ase/calculators/lammpsrun.py:379: UserWarning: semi-periodic ASE cell detected - translation to proper LAMMPS input cell might fail
#   warnings.warn(

# %%
# canonical without relaxation
# adsorb In only for this round
element = 'In'
ads = catkit.gratoms.Gratoms(element)

# starting from more random initial positions
num_ads_atoms = 9 # this number of nitrogens on the surface

num_sweeps = 100
surface_name = "InGaN_0001_3x3"
alpha = 0.99

slab = pristine_slab.copy()
slab.write("InGaN_0001_3x3_starting_slab.cif")

# try positive chem pot
chem_pot = 5
history, energy_hist, frac_accept_hist, adsorption_count_hist = mcmc_run(num_sweeps=num_sweeps, temp=1, pot=chem_pot, alpha=alpha, slab=slab, calc=lammps_calc, surface_name=surface_name, element=element, canonical=True, num_ads_atoms=num_ads_atoms, relax=False, ads_coords=select_positions)
# Out:
# INFO:Running with num_sweeps = 100, temp = 1, pot = 5, alpha = 0.99
# INFO:there are 37 atoms
# INFO:using slab calc <ase.calculators.lammpsrun.LAMMPS object at 0x7f6ddcf4de20>
# /home/dux/miniconda3/envs/mlenv/lib/python3.8/site-packages/catkit/gen/adsorption.py:60: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   self.r1_topology = np.array(self.r1_topology)
# /home/dux/miniconda3/envs/mlenv/lib/python3.8/site-packages/catkit/gen/adsorption.py:61: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   self.r2_topology = np.array(self.r2_topology)
# INFO:In pristine slab, there are a total of 94 sites
# INFO:running for 94 iterations per run over a total of 100 runs
# INFO:adsorbate is In
# INFO:In sweep 1 out of 100
# INFO:optim structure has Energy = -236.3255394717331
# INFO:In sweep 2 out of 100
# INFO:optim structure has Energy = -237.3095532512881
# INFO:In sweep 3 out of 100
# INFO:optim structure has Energy = -236.7468996680297
# INFO:In sweep 4 out of 100
# INFO:optim structure has Energy = -234.5135228519152
# INFO:In sweep 5 out of 100
# INFO:optim structure has Energy = -229.0833921294377
# INFO:In sweep 6 out of 100
# INFO:optim structure has Energy = -235.6913779687873
# INFO:In sweep 7 out of 100
# INFO:optim structure has Energy = -233.061475856513
# INFO:In sweep 8 out of 100
# INFO:optim structure has Energy = -236.8316933979538
# INFO:In sweep 9 out of 100
# INFO:optim structure has Energy = -230.0723663937058
# INFO:In sweep 10 out of 100
# INFO:optim structure has Energy = -231.4268702574156
# INFO:In sweep 11 out of 100
# INFO:optim structure has Energy = -236.9623582303657
# INFO:In sweep 12 out of 100
# INFO:optim structure has Energy = -231.2026461242168
# INFO:In sweep 13 out of 100
# INFO:optim structure has Energy = -237.0197001372769
# INFO:In sweep 14 out of 100
# INFO:optim structure has Energy = -234.9150750512734
# INFO:In sweep 15 out of 100
# INFO:optim structure has Energy = -234.5294622066453
# INFO:In sweep 16 out of 100
# INFO:optim structure has Energy = -232.2001549158481
# INFO:In sweep 17 out of 100
# INFO:optim structure has Energy = -235.8427675651843
# INFO:In sweep 18 out of 100
# INFO:optim structure has Energy = -234.7656002671251
# INFO:In sweep 19 out of 100
# INFO:optim structure has Energy = -234.1353712070017
# INFO:In sweep 20 out of 100
# INFO:optim structure has Energy = -235.4410165983549
# INFO:In sweep 21 out of 100
# INFO:optim structure has Energy = -235.0492402025702
# INFO:In sweep 22 out of 100
# INFO:optim structure has Energy = -236.746171394434
# INFO:In sweep 23 out of 100
# INFO:optim structure has Energy = -234.3219968771793
# INFO:In sweep 24 out of 100
# INFO:optim structure has Energy = -232.0383044580337
# INFO:In sweep 25 out of 100
# INFO:optim structure has Energy = -234.6266775953053
# INFO:In sweep 26 out of 100
# INFO:optim structure has Energy = -236.1596397329368
# INFO:In sweep 27 out of 100
# INFO:optim structure has Energy = -237.5251501196185
# INFO:In sweep 28 out of 100
# INFO:optim structure has Energy = -236.1257220653041
# INFO:In sweep 29 out of 100
# INFO:optim structure has Energy = -237.4227145171509
# INFO:In sweep 30 out of 100
# INFO:optim structure has Energy = -235.701177979637
# INFO:In sweep 31 out of 100
# INFO:optim structure has Energy = -235.6223927325061
# INFO:In sweep 32 out of 100
# INFO:optim structure has Energy = -234.3940531608479
# INFO:In sweep 33 out of 100
# INFO:optim structure has Energy = -233.6948025151173
# INFO:In sweep 34 out of 100
# INFO:optim structure has Energy = -235.8430453968576
# INFO:In sweep 35 out of 100
# INFO:optim structure has Energy = -233.1528799927482
# INFO:In sweep 36 out of 100
# INFO:optim structure has Energy = -236.6425022741424
# INFO:In sweep 37 out of 100
# INFO:optim structure has Energy = -236.2730437148451
# INFO:In sweep 38 out of 100
# INFO:optim structure has Energy = -238.12868407288
# INFO:In sweep 39 out of 100
# INFO:optim structure has Energy = -237.8761757815419
# INFO:In sweep 40 out of 100
# INFO:optim structure has Energy = -236.7588938273199
# INFO:In sweep 41 out of 100
# INFO:optim structure has Energy = -238.7673352264852
# INFO:In sweep 42 out of 100
# INFO:optim structure has Energy = -238.353782486445
# INFO:In sweep 43 out of 100
# INFO:optim structure has Energy = -239.3786284899726
# INFO:In sweep 44 out of 100
# INFO:optim structure has Energy = -238.3059613843782
# INFO:In sweep 45 out of 100
# INFO:optim structure has Energy = -235.3108593882502
# INFO:In sweep 46 out of 100
# INFO:optim structure has Energy = -237.557710620889
# INFO:In sweep 47 out of 100
# INFO:optim structure has Energy = -237.2423292943376
# INFO:In sweep 48 out of 100
# INFO:optim structure has Energy = -238.6983277709229
# INFO:In sweep 49 out of 100
# INFO:optim structure has Energy = -239.731932134161
# INFO:In sweep 50 out of 100
# INFO:optim structure has Energy = -237.9270422545137
# INFO:In sweep 51 out of 100
# INFO:optim structure has Energy = -238.1103447272763
# INFO:In sweep 52 out of 100
# INFO:optim structure has Energy = -237.814280791877
# INFO:In sweep 53 out of 100
# INFO:optim structure has Energy = -237.7990820345385
# INFO:In sweep 54 out of 100
# INFO:optim structure has Energy = -237.4207973862696
# INFO:In sweep 55 out of 100
# INFO:optim structure has Energy = -238.1453982724109
# INFO:In sweep 56 out of 100
# INFO:optim structure has Energy = -239.1015252997474
# INFO:In sweep 57 out of 100
# INFO:optim structure has Energy = -237.886965104498
# INFO:In sweep 58 out of 100
# INFO:optim structure has Energy = -239.8475621306572
# INFO:In sweep 59 out of 100
# INFO:optim structure has Energy = -240.2672719322969
# INFO:In sweep 60 out of 100
# INFO:optim structure has Energy = -236.782175129292
# INFO:In sweep 61 out of 100
# INFO:optim structure has Energy = -239.0913388041259
# INFO:In sweep 62 out of 100
# INFO:optim structure has Energy = -238.7606803685372
# INFO:In sweep 63 out of 100
# INFO:optim structure has Energy = -237.5973925104382
# INFO:In sweep 64 out of 100
# INFO:optim structure has Energy = -234.3270735784864
# INFO:In sweep 65 out of 100
# INFO:optim structure has Energy = -237.461473175192
# INFO:In sweep 66 out of 100
# INFO:optim structure has Energy = -237.9885435895851
# INFO:In sweep 67 out of 100
# INFO:optim structure has Energy = -234.9409736343339
# INFO:In sweep 68 out of 100
# INFO:optim structure has Energy = -238.0517323024109
# INFO:In sweep 69 out of 100
# INFO:optim structure has Energy = -235.9310347092153
# INFO:In sweep 70 out of 100
# INFO:optim structure has Energy = -235.4735851446795
# INFO:In sweep 71 out of 100
# INFO:optim structure has Energy = -237.0352207759158
# INFO:In sweep 72 out of 100
# INFO:optim structure has Energy = -236.8841364239895
# INFO:In sweep 73 out of 100
# INFO:optim structure has Energy = -237.5109140704864
# INFO:In sweep 74 out of 100
# INFO:optim structure has Energy = -237.311721246792
# INFO:In sweep 75 out of 100
# INFO:optim structure has Energy = -239.4670359884366
# INFO:In sweep 76 out of 100
# INFO:optim structure has Energy = -239.4071713713331
# INFO:In sweep 77 out of 100
# INFO:optim structure has Energy = -239.7864469649745
# INFO:In sweep 78 out of 100
# INFO:optim structure has Energy = -239.1540440338867
# INFO:In sweep 79 out of 100
# INFO:optim structure has Energy = -239.2600187946101
# INFO:In sweep 80 out of 100
# INFO:optim structure has Energy = -237.1899459417582
# INFO:In sweep 81 out of 100
# INFO:optim structure has Energy = -235.8548655041127
# INFO:In sweep 82 out of 100
# INFO:optim structure has Energy = -238.5719358441397
# INFO:In sweep 83 out of 100
# INFO:optim structure has Energy = -239.148396073228
# INFO:In sweep 84 out of 100
# INFO:optim structure has Energy = -239.2924975303745
# INFO:In sweep 85 out of 100
# INFO:optim structure has Energy = -239.476628063821
# INFO:In sweep 86 out of 100
# INFO:optim structure has Energy = -238.2411407931374
# INFO:In sweep 87 out of 100
# INFO:optim structure has Energy = -238.0488578767816
# INFO:In sweep 88 out of 100
# INFO:optim structure has Energy = -238.9306463147323
# INFO:In sweep 89 out of 100
# INFO:optim structure has Energy = -239.2750212534257
# INFO:In sweep 90 out of 100
# INFO:optim structure has Energy = -239.3496043942718
# INFO:In sweep 91 out of 100
# INFO:optim structure has Energy = -238.8748811841333
# INFO:In sweep 92 out of 100
# INFO:optim structure has Energy = -240.9096584443685
# INFO:In sweep 93 out of 100
# INFO:optim structure has Energy = -239.540840637253
# INFO:In sweep 94 out of 100
# INFO:optim structure has Energy = -240.002810503502
# INFO:In sweep 95 out of 100
# INFO:optim structure has Energy = -239.0274665147779
# INFO:In sweep 96 out of 100
# INFO:optim structure has Energy = -240.7544668553831
# INFO:In sweep 97 out of 100
# INFO:optim structure has Energy = -240.7544668553831
# INFO:In sweep 98 out of 100
# INFO:optim structure has Energy = -239.105400802661
# INFO:In sweep 99 out of 100
# INFO:optim structure has Energy = -237.7918555180729
# INFO:In sweep 100 out of 100
# INFO:optim structure has Energy = -238.405756550788

# %%
import matplotlib.pyplot as plt
runs = range(1, num_sweeps+1)

# do the plots
fig, ax = plt.subplots(2, 2, figsize=(10, 8))
ax[0, 0].plot(runs, energy_hist)
ax[0, 0].set_xlabel("Iter")
ax[0, 0].set_ylabel("Energy (E)")
ax[0, 0].set_title("Energy (E) vs Sweeps")

ax[0, 1].plot(runs, frac_accept_hist)
ax[0, 1].set_xlabel("Iter")
ax[0, 1].set_ylabel("Fraction accepted")
ax[0, 1].set_title("Fraction accepted vs Sweeps")

ax[1, 1].plot(runs, np.array(list(adsorption_count_hist.values())).T)
ax[1, 1].set_xlabel("Iter")
ax[1, 1].set_ylabel("Adsorption count")
ax[1, 1].legend(adsorption_count_hist.keys())
ax[1, 1].set_title("Adsorption count vs Iterations")

fig.show()
fig.tight_layout()
